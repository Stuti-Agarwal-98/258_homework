# %% [markdown]
# ##NYC taxi dataset competition.
# #implement the solution using xgboost
# Code referenced from : https://www.kaggle.com/sandeepkumar121995/eda-data-cleaning-xg-boost

# %% [markdown]
# # load some default Python modules

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
% matplotlib inline

plt.style.use('seaborn-whitegrid')

import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #loading the nyc taxi dataset

# %%
import pandas
import random


df = pandas.read_csv('/content/drive/MyDrive/new-york-city-taxi-fare-prediction/Copy of train-sample.csv')
df.to_csv("train_sample.csv")

# %%
# datatypes
df.dtypes
# Out:
# key                   object
# fare_amount          float64
# pickup_datetime       object
# pickup_longitude     float64
# pickup_latitude      float64
# dropoff_longitude    float64
# dropoff_latitude     float64
# passenger_count        int64
# dtype: object

# %%
df.describe()
# Out:
#         fare_amount  pickup_longitude  ...  dropoff_latitude  passenger_count
# count  1.048575e+06      1.048575e+06  ...      1.048565e+06     1.048575e+06
# mean   1.134548e+01     -7.252724e+01  ...      3.992496e+01     1.684902e+00
# std    9.820072e+00      1.200798e+01  ...      8.529585e+00     1.323155e+00
# min   -4.490000e+01     -3.377681e+03  ...     -3.114339e+03     0.000000e+00
# 25%    6.000000e+00     -7.399207e+01  ...      4.073406e+01     1.000000e+00
# 50%    8.500000e+00     -7.398180e+01  ...      4.075318e+01     1.000000e+00
# 75%    1.250000e+01     -7.396711e+01  ...      4.076812e+01     2.000000e+00
# max    5.000000e+02      2.522271e+03  ...      1.989728e+03     2.080000e+02
#
# [8 rows x 6 columns]

# %%
df = df.dropna()

##Keep a test set for final testing( TFX internally splits train and validation data )
np.random.seed(seed=2)
msk = np.random.rand(len(df)) < 0.9
train = df[msk]
test = df[~msk]

print(len(train))
print(len(test))

train.to_csv("/content/data.csv", index=False, header=True)
test.to_csv("test.csv", index=False, header=False)
#df_test = pd.read_csv(io.BytesIO(uploaded['test.csv']))
test.head()
# Out:
# 943389
# 105176
#         key  fare_amount  ... dropoff_latitude  passenger_count
# 40  39:49.0          8.1  ...        40.759608                1
# 49  26:00.0          9.0  ...        40.755947                1
# 58  53:14.0         13.7  ...        40.791899                2
# 59  13:29.0          6.5  ...        40.724802                1
# 68  19:05.0         11.5  ...        40.746948                6
#
# [5 rows x 8 columns]

# %%
print("shape of test data", test.shape)
test.head()
# Out:
# shape of test data (105176, 8)
#         key  fare_amount  ... dropoff_latitude  passenger_count
# 40  39:49.0          8.1  ...        40.759608                1
# 49  26:00.0          9.0  ...        40.755947                1
# 58  53:14.0         13.7  ...        40.791899                2
# 59  13:29.0          6.5  ...        40.724802                1
# 68  19:05.0         11.5  ...        40.746948                6
#
# [5 rows x 8 columns]

# %% [markdown]
# #feature engineering

# %%
def prepare_time_features(df):
    df['pickup_datetime'] = df['pickup_datetime'].str.slice(0, 16)
    df['pickup_datetime'] = pd.to_datetime(df['pickup_datetime'], utc=True, format='%Y-%m-%d %H:%M')
    df['hour_of_day'] = df.pickup_datetime.dt.hour
    df['month'] = df.pickup_datetime.dt.month
    df["year"] = df.pickup_datetime.dt.year
    df["weekday"] = df.pickup_datetime.dt.weekday

    return df

# %%
train = prepare_time_features(train)
test = prepare_time_features(test)

# %%
# calculate-distance-between-two-latitude-longitude-points-haversine-formula 
# Returns distance in miles
def distance(lat1, lon1, lat2, lon2):
    p = 0.017453292519943295 # Pi/180
    a = 0.5 - np.cos((lat2 - lat1) * p)/2 + np.cos(lat1 * p) * np.cos(lat2 * p) * (1 - np.cos((lon2 - lon1) * p)) / 2
    return 0.6213712 * 12742 * np.arcsin(np.sqrt(a))   # 2*R*asin...

# %%
train['distance_miles'] = distance(train.pickup_latitude, train.pickup_longitude, \
                                      train.dropoff_latitude, train.dropoff_longitude)

# %%
test['distance_miles'] = distance(test.pickup_latitude, test.pickup_longitude, \
                                      test.dropoff_latitude, test.dropoff_longitude)

# %%
def transform(data):
    # Distances to nearby airports, 
    jfk = (-73.7781, 40.6413)
    ewr = (-74.1745, 40.6895)
    lgr = (-73.8740, 40.7769)

    data['pickup_distance_to_jfk'] = distance(jfk[1], jfk[0],
                                         data['pickup_latitude'], data['pickup_longitude'])
    data['dropoff_distance_to_jfk'] = distance(jfk[1], jfk[0],
                                           data['dropoff_latitude'], data['dropoff_longitude'])
    data['pickup_distance_to_ewr'] = distance(ewr[1], ewr[0], 
                                          data['pickup_latitude'], data['pickup_longitude'])
    data['dropoff_distance_to_ewr'] = distance(ewr[1], ewr[0],
                                           data['dropoff_latitude'], data['dropoff_longitude'])
    data['pickup_distance_to_lgr'] = distance(lgr[1], lgr[0],
                                          data['pickup_latitude'], data['pickup_longitude'])
    data['dropoff_distance_to_lgr'] = distance(lgr[1], lgr[0],
                                           data['dropoff_latitude'], data['dropoff_longitude'])
    
    return data

train = transform(train)
test = transform(test)

# %%
print("old size: %d" % len(train))
train = train.drop(index= train[(train['distance_miles']==0)&(train['fare_amount']==0)].index, axis=0)
print("New size: %d" % len(train))
# Out:
# old size: 943389
# New size: 943385

# %%
train[train['fare_amount']==0].shape
# Out:
# (24, 19)

# %%
print("old size: %d" % len(train))
train = train.drop(index= train[train['fare_amount']==0].index, axis=0)
print("New size: %d" % len(train))
# Out:
# old size: 943385
# New size: 943361

# %%
train[train['fare_amount'] < 2.5].shape
# Out:
# (50, 19)

# %%
print("old size: %d" % len(train))
train = train.drop(index= train[train['fare_amount'] < 2.5].index, axis=0)
print("New size: %d" % len(train))
# Out:
# old size: 943361
# New size: 943311

# %%
train[train.passenger_count >= 7]
# Out:
#              key  fare_amount  ... pickup_distance_to_lgr  dropoff_distance_to_lgr
# 929022   54:00.0          3.3  ...            5379.493468              5379.493468
# 1007609  13:00.0        104.0  ...               8.551259                16.217073
#
# [2 rows x 19 columns]

# %%
print("old size: %d" % len(train))
train = train.drop(index= train[train.passenger_count >= 7].index, axis=0)
print("New size: %d" % len(train))
# Out:
# old size: 943311
# New size: 943309

# %%
train.describe().T
# Out:
#                             count         mean  ...          75%           max
# fare_amount              943309.0    11.348479  ...    12.500000    500.000000
# pickup_longitude         943309.0   -72.528629  ...   -73.967115   2522.271325
# pickup_latitude          943309.0    39.931820  ...    40.767147   2621.628430
# dropoff_longitude        943309.0   -72.528180  ...   -73.963663   1717.003405
# dropoff_latitude         943309.0    39.925218  ...    40.768137   1989.728077
# passenger_count          943309.0     1.683736  ...     2.000000      6.000000
# hour_of_day              943309.0    13.506272  ...    19.000000     23.000000
# month                    943309.0     6.268767  ...     9.000000     12.000000
# year                     943309.0  2011.739801  ...  2013.000000   2015.000000
# weekday                  943309.0     3.039395  ...     5.000000      6.000000
# distance_miles           943309.0    11.865667  ...     2.413124  10487.691487
# pickup_distance_to_jfk   943309.0   118.965632  ...    13.625129  10024.540251
# dropoff_distance_to_jfk  943309.0   119.042580  ...    13.649215  10500.667366
# pickup_distance_to_ewr   943309.0   117.836333  ...    12.212467  10041.311657
# dropoff_distance_to_ewr  943309.0   117.969474  ...    12.412825  10479.629717
# pickup_distance_to_lgr   943309.0   112.275394  ...     6.927147  10024.591791
# dropoff_distance_to_lgr  943309.0   112.332959  ...     6.910021  10494.327050
#
# [17 rows x 8 columns]

# %%
# create copy of the data set
df_train = train.drop(columns= ['key','pickup_datetime'], axis= 1).copy()
df_test = test.drop(columns= ['key','pickup_datetime'], axis= 1).copy()
print(df_train.shape)
print(df_test.shape)
# Out:
# (943309, 17)
# (105176, 17)

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(df_train.drop('fare_amount', axis=1),
                                                    df_train['fare_amount'], test_size=0.2, random_state = 42)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (754647, 16)
# (188662, 16)
# (754647,)
# (188662,)

# %%
import xgboost as xgb

# %%
params = {
   
    'max_depth': 7,
    'gamma' :0,
    'eta':.03, 
    'subsample': 1,
    'colsample_bytree': 0.9, 
    'objective':'reg:linear',
    'eval_metric':'rmse',
    'silent': 0
}

# %% [markdown]
# #defining the XGBoost model

# %%
def XGBmodel(X_train,X_test,y_train,y_test,params):
    matrix_train = xgb.DMatrix(X_train,label=y_train)
    matrix_test = xgb.DMatrix(X_test,label=y_test)
    model=xgb.train(params=params,
                    dtrain=matrix_train,num_boost_round=5000, 
                    early_stopping_rounds=10,evals=[(matrix_train, 'train'),(matrix_test,'test')])
    return model

model = XGBmodel(X_train,X_test,y_train,y_test,params)
# Out:
# [05:33:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	train-rmse:14.2401	test-rmse:14.2651
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 10 rounds.
# [1]	train-rmse:13.8592	test-rmse:13.8861
# [2]	train-rmse:13.5131	test-rmse:13.5425
# [3]	train-rmse:13.1584	test-rmse:13.1886
# [4]	train-rmse:12.8124	test-rmse:12.8461
# [5]	train-rmse:12.4783	test-rmse:12.5151
# [6]	train-rmse:12.1572	test-rmse:12.1962
# [7]	train-rmse:11.8462	test-rmse:11.8873
# [8]	train-rmse:11.5456	test-rmse:11.5894
# [9]	train-rmse:11.2547	test-rmse:11.3006
# [10]	train-rmse:10.9916	test-rmse:11.0399
# [11]	train-rmse:10.7201	test-rmse:10.7705
# [12]	train-rmse:10.458	test-rmse:10.5115
# [13]	train-rmse:10.204	test-rmse:10.2609
# [14]	train-rmse:9.96049	test-rmse:10.02
# [15]	train-rmse:9.72559	test-rmse:9.78753
# [16]	train-rmse:9.49896	test-rmse:9.56377
# [17]	train-rmse:9.27757	test-rmse:9.34554
# [18]	train-rmse:9.06739	test-rmse:9.13773
# [19]	train-rmse:8.86378	test-rmse:8.93715
# [20]	train-rmse:8.66542	test-rmse:8.74261
# [21]	train-rmse:8.47519	test-rmse:8.55596
# [22]	train-rmse:8.30353	test-rmse:8.38713
# [23]	train-rmse:8.12726	test-rmse:8.21362
# [24]	train-rmse:7.95716	test-rmse:8.0462
# [25]	train-rmse:7.79446	test-rmse:7.8864
# [26]	train-rmse:7.63671	test-rmse:7.73281
# [27]	train-rmse:7.48496	test-rmse:7.58526
# [28]	train-rmse:7.33953	test-rmse:7.44318
# [29]	train-rmse:7.19952	test-rmse:7.306
# [30]	train-rmse:7.06448	test-rmse:7.17445
# [31]	train-rmse:6.93567	test-rmse:7.0491
# [32]	train-rmse:6.81199	test-rmse:6.92968
# [33]	train-rmse:6.69337	test-rmse:6.81439
# [34]	train-rmse:6.57964	test-rmse:6.70339
# [35]	train-rmse:6.47661	test-rmse:6.60367
# [36]	train-rmse:6.37108	test-rmse:6.50172
# [37]	train-rmse:6.27014	test-rmse:6.40526
# [38]	train-rmse:6.17342	test-rmse:6.313
# [39]	train-rmse:6.08038	test-rmse:6.22426
# [40]	train-rmse:5.99161	test-rmse:6.13957
# [41]	train-rmse:5.90656	test-rmse:6.05834
# [42]	train-rmse:5.82492	test-rmse:5.97997
# [43]	train-rmse:5.74833	test-rmse:5.90705
# [44]	train-rmse:5.67489	test-rmse:5.83773
# [45]	train-rmse:5.60366	test-rmse:5.7706
# [46]	train-rmse:5.53576	test-rmse:5.70713
# [47]	train-rmse:5.47081	test-rmse:5.6465
# [48]	train-rmse:5.40859	test-rmse:5.58822
# [49]	train-rmse:5.3497	test-rmse:5.53283
# [50]	train-rmse:5.29313	test-rmse:5.47951
# [51]	train-rmse:5.24034	test-rmse:5.43014
# [52]	train-rmse:5.18906	test-rmse:5.38208
# [53]	train-rmse:5.13954	test-rmse:5.33665
# [54]	train-rmse:5.09362	test-rmse:5.2939
# [55]	train-rmse:5.04867	test-rmse:5.25278
# [56]	train-rmse:5.006	test-rmse:5.21318
# [57]	train-rmse:4.96557	test-rmse:5.17539
# [58]	train-rmse:4.92777	test-rmse:5.14046
# [59]	train-rmse:4.8903	test-rmse:5.10668
# [60]	train-rmse:4.85591	test-rmse:5.07562
# [61]	train-rmse:4.82236	test-rmse:5.04491
# [62]	train-rmse:4.7911	test-rmse:5.01667
# [63]	train-rmse:4.76046	test-rmse:4.98873
# [64]	train-rmse:4.72896	test-rmse:4.96336
# [65]	train-rmse:4.70097	test-rmse:4.93879
# [66]	train-rmse:4.67361	test-rmse:4.91434
# [67]	train-rmse:4.64763	test-rmse:4.89138
# [68]	train-rmse:4.62307	test-rmse:4.87005
# [69]	train-rmse:4.59992	test-rmse:4.85006
# [70]	train-rmse:4.5776	test-rmse:4.83085
# [71]	train-rmse:4.55606	test-rmse:4.81266
# [72]	train-rmse:4.53546	test-rmse:4.79546
# [73]	train-rmse:4.516	test-rmse:4.77917
# [74]	train-rmse:4.49711	test-rmse:4.76344
# [75]	train-rmse:4.47898	test-rmse:4.74805
# [76]	train-rmse:4.46223	test-rmse:4.73369
# [77]	train-rmse:4.44558	test-rmse:4.71977
# [78]	train-rmse:4.43044	test-rmse:4.70692
# [79]	train-rmse:4.41632	test-rmse:4.69467
# [80]	train-rmse:4.40136	test-rmse:4.68285
# [81]	train-rmse:4.38741	test-rmse:4.67117
# [82]	train-rmse:4.37421	test-rmse:4.66045
# [83]	train-rmse:4.36163	test-rmse:4.65046
# [84]	train-rmse:4.3494	test-rmse:4.64041
# [85]	train-rmse:4.33804	test-rmse:4.63135
# [86]	train-rmse:4.32693	test-rmse:4.62284
# [87]	train-rmse:4.31569	test-rmse:4.61434
# [88]	train-rmse:4.30572	test-rmse:4.60633
# [89]	train-rmse:4.29599	test-rmse:4.59886
# [90]	train-rmse:4.28596	test-rmse:4.59133
# [91]	train-rmse:4.27759	test-rmse:4.58508
# [92]	train-rmse:4.26809	test-rmse:4.57888
# [93]	train-rmse:4.26057	test-rmse:4.57321
# [94]	train-rmse:4.25109	test-rmse:4.56673
# [95]	train-rmse:4.2431	test-rmse:4.56138
# [96]	train-rmse:4.2345	test-rmse:4.55504
# [97]	train-rmse:4.22713	test-rmse:4.55042
# [98]	train-rmse:4.21909	test-rmse:4.54492
# [99]	train-rmse:4.21254	test-rmse:4.53971
# [100]	train-rmse:4.20661	test-rmse:4.53555
# [101]	train-rmse:4.19991	test-rmse:4.53151
# [102]	train-rmse:4.19348	test-rmse:4.52735
# [103]	train-rmse:4.18685	test-rmse:4.52299
# [104]	train-rmse:4.18041	test-rmse:4.51903
# [105]	train-rmse:4.17543	test-rmse:4.51605
# [106]	train-rmse:4.1703	test-rmse:4.51222
# [107]	train-rmse:4.16452	test-rmse:4.50837
# [108]	train-rmse:4.15933	test-rmse:4.50518
# [109]	train-rmse:4.15177	test-rmse:4.50122
# [110]	train-rmse:4.14762	test-rmse:4.49849
# [111]	train-rmse:4.14156	test-rmse:4.49542
# [112]	train-rmse:4.1371	test-rmse:4.49285
# [113]	train-rmse:4.13267	test-rmse:4.49017
# [114]	train-rmse:4.12823	test-rmse:4.48719
# [115]	train-rmse:4.12383	test-rmse:4.48423
# [116]	train-rmse:4.11972	test-rmse:4.48181
# [117]	train-rmse:4.11627	test-rmse:4.47991
# [118]	train-rmse:4.11127	test-rmse:4.47785
# [119]	train-rmse:4.1076	test-rmse:4.47589
# [120]	train-rmse:4.10439	test-rmse:4.47369
# [121]	train-rmse:4.09872	test-rmse:4.47069
# [122]	train-rmse:4.09321	test-rmse:4.4677
# [123]	train-rmse:4.08925	test-rmse:4.46532
# [124]	train-rmse:4.08617	test-rmse:4.46399
# [125]	train-rmse:4.08309	test-rmse:4.46231
# [126]	train-rmse:4.07951	test-rmse:4.46042
# [127]	train-rmse:4.07648	test-rmse:4.45868
# [128]	train-rmse:4.07322	test-rmse:4.45709
# [129]	train-rmse:4.07018	test-rmse:4.45557
# [130]	train-rmse:4.06777	test-rmse:4.45421
# [131]	train-rmse:4.06531	test-rmse:4.45322
# [132]	train-rmse:4.06214	test-rmse:4.45172
# [133]	train-rmse:4.05807	test-rmse:4.45017
# [134]	train-rmse:4.05483	test-rmse:4.44919
# [135]	train-rmse:4.05259	test-rmse:4.44804
# [136]	train-rmse:4.04832	test-rmse:4.44606
# [137]	train-rmse:4.04525	test-rmse:4.44472
# [138]	train-rmse:4.04278	test-rmse:4.44337
# [139]	train-rmse:4.03853	test-rmse:4.44061
# [140]	train-rmse:4.0345	test-rmse:4.43908
# [141]	train-rmse:4.03242	test-rmse:4.43825
# [142]	train-rmse:4.03025	test-rmse:4.43732
# [143]	train-rmse:4.02657	test-rmse:4.43602
# [144]	train-rmse:4.02409	test-rmse:4.43504
# [145]	train-rmse:4.02214	test-rmse:4.43419
# [146]	train-rmse:4.01984	test-rmse:4.43343
# [147]	train-rmse:4.01663	test-rmse:4.43164
# [148]	train-rmse:4.01459	test-rmse:4.4309
# [149]	train-rmse:4.01267	test-rmse:4.43022
# [150]	train-rmse:4.01005	test-rmse:4.429
# [151]	train-rmse:4.00835	test-rmse:4.42855
# [152]	train-rmse:4.00605	test-rmse:4.42802
# [153]	train-rmse:4.00289	test-rmse:4.42677
# [154]	train-rmse:3.99988	test-rmse:4.42563
# [155]	train-rmse:3.99671	test-rmse:4.42438
# [156]	train-rmse:3.99513	test-rmse:4.42381
# [157]	train-rmse:3.99196	test-rmse:4.42263
# [158]	train-rmse:3.99003	test-rmse:4.42192
# [159]	train-rmse:3.98818	test-rmse:4.42116
# [160]	train-rmse:3.98585	test-rmse:4.42045
# [161]	train-rmse:3.98292	test-rmse:4.41991
# [162]	train-rmse:3.98149	test-rmse:4.41964
# [163]	train-rmse:3.9788	test-rmse:4.41903
# [164]	train-rmse:3.97662	test-rmse:4.41884
# [165]	train-rmse:3.97419	test-rmse:4.41822
# [166]	train-rmse:3.97128	test-rmse:4.41675
# [167]	train-rmse:3.96895	test-rmse:4.41611
# [168]	train-rmse:3.96695	test-rmse:4.41519
# [169]	train-rmse:3.96542	test-rmse:4.41475
# [170]	train-rmse:3.96467	test-rmse:4.41441
# [171]	train-rmse:3.96303	test-rmse:4.41434
# [172]	train-rmse:3.96216	test-rmse:4.41401
# [173]	train-rmse:3.95943	test-rmse:4.41318
# [174]	train-rmse:3.95796	test-rmse:4.41298
# [175]	train-rmse:3.95561	test-rmse:4.41268
# [176]	train-rmse:3.95455	test-rmse:4.41207
# [177]	train-rmse:3.95329	test-rmse:4.41194
# [178]	train-rmse:3.95169	test-rmse:4.41187
# [179]	train-rmse:3.94887	test-rmse:4.41062
# [180]	train-rmse:3.94713	test-rmse:4.41022
# [181]	train-rmse:3.94601	test-rmse:4.41012
# [182]	train-rmse:3.94351	test-rmse:4.40946
# [183]	train-rmse:3.9423	test-rmse:4.40897
# [184]	train-rmse:3.94117	test-rmse:4.40896
# [185]	train-rmse:3.94048	test-rmse:4.40881
# [186]	train-rmse:3.93848	test-rmse:4.40802
# [187]	train-rmse:3.93621	test-rmse:4.40743
# [188]	train-rmse:3.93494	test-rmse:4.4069
# [189]	train-rmse:3.93313	test-rmse:4.40659
# [190]	train-rmse:3.93118	test-rmse:4.40621
# [191]	train-rmse:3.92937	test-rmse:4.40558
# [192]	train-rmse:3.92826	test-rmse:4.40536
# [193]	train-rmse:3.92707	test-rmse:4.40523
# [194]	train-rmse:3.92587	test-rmse:4.40471
# [195]	train-rmse:3.92379	test-rmse:4.40452
# [196]	train-rmse:3.92099	test-rmse:4.40323
# [197]	train-rmse:3.91872	test-rmse:4.40204
# [198]	train-rmse:3.91698	test-rmse:4.40123
# [199]	train-rmse:3.91481	test-rmse:4.40112
# [200]	train-rmse:3.91285	test-rmse:4.40084
# [201]	train-rmse:3.91035	test-rmse:4.39975
# [202]	train-rmse:3.9088	test-rmse:4.39989
# [203]	train-rmse:3.90671	test-rmse:4.39971
# [204]	train-rmse:3.90461	test-rmse:4.39921
# [205]	train-rmse:3.90355	test-rmse:4.39923
# [206]	train-rmse:3.9015	test-rmse:4.39877
# [207]	train-rmse:3.89973	test-rmse:4.39802
# [208]	train-rmse:3.89849	test-rmse:4.39781
# [209]	train-rmse:3.89678	test-rmse:4.39696
# [210]	train-rmse:3.89474	test-rmse:4.3964
# [211]	train-rmse:3.89328	test-rmse:4.39601
# [212]	train-rmse:3.89234	test-rmse:4.39573
# [213]	train-rmse:3.89053	test-rmse:4.39528
# [214]	train-rmse:3.88914	test-rmse:4.39517
# [215]	train-rmse:3.88812	test-rmse:4.39508
# [216]	train-rmse:3.8857	test-rmse:4.39403
# [217]	train-rmse:3.88418	test-rmse:4.39354
# [218]	train-rmse:3.88293	test-rmse:4.3933
# [219]	train-rmse:3.88175	test-rmse:4.39316
# [220]	train-rmse:3.87987	test-rmse:4.39265
# [221]	train-rmse:3.87838	test-rmse:4.39203
# [222]	train-rmse:3.87684	test-rmse:4.39197
# [223]	train-rmse:3.87525	test-rmse:4.39157
# [224]	train-rmse:3.87354	test-rmse:4.39151
# [225]	train-rmse:3.87251	test-rmse:4.39118
# [226]	train-rmse:3.87076	test-rmse:4.39059
# [227]	train-rmse:3.86961	test-rmse:4.39017
# [228]	train-rmse:3.86839	test-rmse:4.38956
# [229]	train-rmse:3.86769	test-rmse:4.38931
# [230]	train-rmse:3.86598	test-rmse:4.38872
# [231]	train-rmse:3.86509	test-rmse:4.3883
# [232]	train-rmse:3.86356	test-rmse:4.38829
# [233]	train-rmse:3.86184	test-rmse:4.38802
# [234]	train-rmse:3.8603	test-rmse:4.38783
# [235]	train-rmse:3.85963	test-rmse:4.38752
# [236]	train-rmse:3.85753	test-rmse:4.38666
# [237]	train-rmse:3.85628	test-rmse:4.38622
# [238]	train-rmse:3.85503	test-rmse:4.38596
# [239]	train-rmse:3.85301	test-rmse:4.38507
# [240]	train-rmse:3.85152	test-rmse:4.3848
# [241]	train-rmse:3.85042	test-rmse:4.38469
# [242]	train-rmse:3.84903	test-rmse:4.38424
# [243]	train-rmse:3.84736	test-rmse:4.38417
# [244]	train-rmse:3.8465	test-rmse:4.38394
# [245]	train-rmse:3.84543	test-rmse:4.38376
# [246]	train-rmse:3.84482	test-rmse:4.3835
# [247]	train-rmse:3.84326	test-rmse:4.38332
# [248]	train-rmse:3.84177	test-rmse:4.38247
# [249]	train-rmse:3.84023	test-rmse:4.38251
# [250]	train-rmse:3.83955	test-rmse:4.38256
# [251]	train-rmse:3.83783	test-rmse:4.38209
# [252]	train-rmse:3.83632	test-rmse:4.38199
# [253]	train-rmse:3.83488	test-rmse:4.38225
# [254]	train-rmse:3.83309	test-rmse:4.38198
# [255]	train-rmse:3.83171	test-rmse:4.38168
# [256]	train-rmse:3.82925	test-rmse:4.38065
# [257]	train-rmse:3.82858	test-rmse:4.38046
# [258]	train-rmse:3.82681	test-rmse:4.38007
# [259]	train-rmse:3.82463	test-rmse:4.37935
# [260]	train-rmse:3.82389	test-rmse:4.37924
# [261]	train-rmse:3.82316	test-rmse:4.37895
# [262]	train-rmse:3.82201	test-rmse:4.37874
# [263]	train-rmse:3.82134	test-rmse:4.37847
# [264]	train-rmse:3.81979	test-rmse:4.37867
# [265]	train-rmse:3.81745	test-rmse:4.37743
# [266]	train-rmse:3.81599	test-rmse:4.37703
# [267]	train-rmse:3.81426	test-rmse:4.37593
# [268]	train-rmse:3.81225	test-rmse:4.37483
# [269]	train-rmse:3.8106	test-rmse:4.37408
# [270]	train-rmse:3.80959	test-rmse:4.37389
# [271]	train-rmse:3.80869	test-rmse:4.37393
# [272]	train-rmse:3.80781	test-rmse:4.37398
# [273]	train-rmse:3.80652	test-rmse:4.37377
# [274]	train-rmse:3.80508	test-rmse:4.37346
# [275]	train-rmse:3.80387	test-rmse:4.37341
# [276]	train-rmse:3.80332	test-rmse:4.37318
# [277]	train-rmse:3.80202	test-rmse:4.3725
# [278]	train-rmse:3.80089	test-rmse:4.37224
# [279]	train-rmse:3.79956	test-rmse:4.37185
# [280]	train-rmse:3.7992	test-rmse:4.37184
# [281]	train-rmse:3.79856	test-rmse:4.37153
# [282]	train-rmse:3.79807	test-rmse:4.37141
# [283]	train-rmse:3.79732	test-rmse:4.37126
# [284]	train-rmse:3.79551	test-rmse:4.37028
# [285]	train-rmse:3.79394	test-rmse:4.36983
# [286]	train-rmse:3.79318	test-rmse:4.36977
# [287]	train-rmse:3.79157	test-rmse:4.36933
# [288]	train-rmse:3.79039	test-rmse:4.36896
# [289]	train-rmse:3.79	test-rmse:4.36895
# [290]	train-rmse:3.78985	test-rmse:4.36885
# [291]	train-rmse:3.7884	test-rmse:4.36844
# [292]	train-rmse:3.78692	test-rmse:4.36778
# [293]	train-rmse:3.78614	test-rmse:4.3677
# [294]	train-rmse:3.7856	test-rmse:4.36753
# [295]	train-rmse:3.78456	test-rmse:4.36737
# [296]	train-rmse:3.78376	test-rmse:4.36739
# [297]	train-rmse:3.78309	test-rmse:4.36725
# [298]	train-rmse:3.78302	test-rmse:4.36723
# [299]	train-rmse:3.78198	test-rmse:4.36705
# [300]	train-rmse:3.78139	test-rmse:4.36694
# [301]	train-rmse:3.78001	test-rmse:4.36659
# [302]	train-rmse:3.77835	test-rmse:4.36579
# [303]	train-rmse:3.77756	test-rmse:4.36536
# [304]	train-rmse:3.77682	test-rmse:4.36532
# [305]	train-rmse:3.77655	test-rmse:4.36519
# [306]	train-rmse:3.77502	test-rmse:4.3648
# [307]	train-rmse:3.77424	test-rmse:4.36476
# [308]	train-rmse:3.77289	test-rmse:4.36451
# [309]	train-rmse:3.77163	test-rmse:4.36411
# [310]	train-rmse:3.77118	test-rmse:4.36408
# [311]	train-rmse:3.77033	test-rmse:4.36408
# [312]	train-rmse:3.77022	test-rmse:4.36406
# [313]	train-rmse:3.76986	test-rmse:4.36397
# [314]	train-rmse:3.76889	test-rmse:4.36383
# [315]	train-rmse:3.76767	test-rmse:4.36333
# [316]	train-rmse:3.76634	test-rmse:4.36271
# [317]	train-rmse:3.76535	test-rmse:4.36228
# [318]	train-rmse:3.76378	test-rmse:4.36215
# [319]	train-rmse:3.76258	test-rmse:4.36226
# [320]	train-rmse:3.76196	test-rmse:4.36208
# [321]	train-rmse:3.76081	test-rmse:4.36179
# [322]	train-rmse:3.75918	test-rmse:4.36173
# [323]	train-rmse:3.75792	test-rmse:4.36124
# [324]	train-rmse:3.75737	test-rmse:4.36112
# [325]	train-rmse:3.75583	test-rmse:4.36096
# [326]	train-rmse:3.75471	test-rmse:4.36091
# [327]	train-rmse:3.75366	test-rmse:4.36062
# [328]	train-rmse:3.75237	test-rmse:4.36046
# [329]	train-rmse:3.75212	test-rmse:4.36056
# [330]	train-rmse:3.75135	test-rmse:4.36046
# [331]	train-rmse:3.7512	test-rmse:4.36033
# [332]	train-rmse:3.75051	test-rmse:4.36004
# [333]	train-rmse:3.749	test-rmse:4.35994
# [334]	train-rmse:3.74777	test-rmse:4.35975
# [335]	train-rmse:3.74728	test-rmse:4.35967
# [336]	train-rmse:3.74607	test-rmse:4.35962
# [337]	train-rmse:3.74574	test-rmse:4.35956
# [338]	train-rmse:3.74448	test-rmse:4.3597
# [339]	train-rmse:3.74366	test-rmse:4.35955
# [340]	train-rmse:3.74358	test-rmse:4.35951
# [341]	train-rmse:3.74297	test-rmse:4.35919
# [342]	train-rmse:3.74253	test-rmse:4.35914
# [343]	train-rmse:3.74225	test-rmse:4.3591
# [344]	train-rmse:3.74145	test-rmse:4.35873
# [345]	train-rmse:3.7406	test-rmse:4.35875
# [346]	train-rmse:3.74007	test-rmse:4.35872
# [347]	train-rmse:3.73947	test-rmse:4.35841
# [348]	train-rmse:3.73909	test-rmse:4.35833
# [349]	train-rmse:3.73788	test-rmse:4.35765
# [350]	train-rmse:3.73764	test-rmse:4.35766
# [351]	train-rmse:3.73703	test-rmse:4.35736
# [352]	train-rmse:3.73621	test-rmse:4.35726
# [353]	train-rmse:3.7361	test-rmse:4.35722
# [354]	train-rmse:3.7355	test-rmse:4.35702
# [355]	train-rmse:3.73524	test-rmse:4.35701
# [356]	train-rmse:3.7346	test-rmse:4.35688
# [357]	train-rmse:3.73433	test-rmse:4.35685
# [358]	train-rmse:3.73335	test-rmse:4.35669
# [359]	train-rmse:3.73315	test-rmse:4.35662
# [360]	train-rmse:3.73303	test-rmse:4.35669
# [361]	train-rmse:3.73234	test-rmse:4.35654
# [362]	train-rmse:3.73175	test-rmse:4.35621
# [363]	train-rmse:3.73133	test-rmse:4.35632
# [364]	train-rmse:3.73127	test-rmse:4.35631
# [365]	train-rmse:3.73107	test-rmse:4.35638
# [366]	train-rmse:3.73056	test-rmse:4.35614
# [367]	train-rmse:3.73044	test-rmse:4.35612
# [368]	train-rmse:3.72995	test-rmse:4.35599
# [369]	train-rmse:3.72863	test-rmse:4.35536
# [370]	train-rmse:3.72819	test-rmse:4.35521
# [371]	train-rmse:3.72809	test-rmse:4.3552
# [372]	train-rmse:3.72731	test-rmse:4.35518
# [373]	train-rmse:3.72642	test-rmse:4.35497
# [374]	train-rmse:3.72576	test-rmse:4.35482
# [375]	train-rmse:3.72544	test-rmse:4.3547
# [376]	train-rmse:3.7248	test-rmse:4.35462
# [377]	train-rmse:3.72474	test-rmse:4.3546
# [378]	train-rmse:3.72431	test-rmse:4.3545
# [379]	train-rmse:3.72295	test-rmse:4.35377
# [380]	train-rmse:3.72222	test-rmse:4.35376
# [381]	train-rmse:3.72179	test-rmse:4.35383
# [382]	train-rmse:3.72168	test-rmse:4.3538
# [383]	train-rmse:3.72082	test-rmse:4.35381
# [384]	train-rmse:3.72008	test-rmse:4.35391
# [385]	train-rmse:3.71964	test-rmse:4.35366
# [386]	train-rmse:3.71902	test-rmse:4.3537
# [387]	train-rmse:3.71774	test-rmse:4.3531
# [388]	train-rmse:3.71767	test-rmse:4.3531
# [389]	train-rmse:3.71736	test-rmse:4.35297
# [390]	train-rmse:3.71725	test-rmse:4.35298
# [391]	train-rmse:3.71696	test-rmse:4.35298
# [392]	train-rmse:3.71677	test-rmse:4.35296
# [393]	train-rmse:3.71625	test-rmse:4.3529
# [394]	train-rmse:3.71524	test-rmse:4.35281
# [395]	train-rmse:3.71471	test-rmse:4.3529
# [396]	train-rmse:3.71377	test-rmse:4.35258
# [397]	train-rmse:3.71209	test-rmse:4.35172
# [398]	train-rmse:3.71178	test-rmse:4.35167
# [399]	train-rmse:3.71122	test-rmse:4.35132
# [400]	train-rmse:3.71082	test-rmse:4.3512
# [401]	train-rmse:3.71033	test-rmse:4.35121
# [402]	train-rmse:3.71009	test-rmse:4.35126
# [403]	train-rmse:3.70978	test-rmse:4.35116
# [404]	train-rmse:3.70945	test-rmse:4.35114
# [405]	train-rmse:3.70798	test-rmse:4.35078
# [406]	train-rmse:3.70751	test-rmse:4.35058
# [407]	train-rmse:3.70718	test-rmse:4.35055
# [408]	train-rmse:3.7056	test-rmse:4.35035
# [409]	train-rmse:3.70488	test-rmse:4.35031
# [410]	train-rmse:3.70396	test-rmse:4.35
# [411]	train-rmse:3.70315	test-rmse:4.34973
# [412]	train-rmse:3.70173	test-rmse:4.34875
# [413]	train-rmse:3.70107	test-rmse:4.34864
# [414]	train-rmse:3.70084	test-rmse:4.34852
# [415]	train-rmse:3.70031	test-rmse:4.34849
# [416]	train-rmse:3.6999	test-rmse:4.34858
# [417]	train-rmse:3.69907	test-rmse:4.3483
# [418]	train-rmse:3.6986	test-rmse:4.34809
# [419]	train-rmse:3.69803	test-rmse:4.34796
# [420]	train-rmse:3.69703	test-rmse:4.34765
# [421]	train-rmse:3.69699	test-rmse:4.34765
# [422]	train-rmse:3.69617	test-rmse:4.34767
# [423]	train-rmse:3.69611	test-rmse:4.34773
# [424]	train-rmse:3.69558	test-rmse:4.34778
# [425]	train-rmse:3.69508	test-rmse:4.34777
# [426]	train-rmse:3.69436	test-rmse:4.34758
# [427]	train-rmse:3.69407	test-rmse:4.34758
# [428]	train-rmse:3.69355	test-rmse:4.34739
# [429]	train-rmse:3.69348	test-rmse:4.34743
# [430]	train-rmse:3.69336	test-rmse:4.3474
# [431]	train-rmse:3.69281	test-rmse:4.34704
# [432]	train-rmse:3.69239	test-rmse:4.34692
# [433]	train-rmse:3.69212	test-rmse:4.34692
# [434]	train-rmse:3.69146	test-rmse:4.34671
# [435]	train-rmse:3.69106	test-rmse:4.34667
# [436]	train-rmse:3.68994	test-rmse:4.34602
# [437]	train-rmse:3.68942	test-rmse:4.34581
# [438]	train-rmse:3.68871	test-rmse:4.34573
# [439]	train-rmse:3.68778	test-rmse:4.34532
# [440]	train-rmse:3.68721	test-rmse:4.34523
# [441]	train-rmse:3.68654	test-rmse:4.34522
# [442]	train-rmse:3.6858	test-rmse:4.345
# [443]	train-rmse:3.68559	test-rmse:4.34487
# [444]	train-rmse:3.68532	test-rmse:4.34486
# [445]	train-rmse:3.68522	test-rmse:4.34484
# [446]	train-rmse:3.68406	test-rmse:4.34444
# [447]	train-rmse:3.68357	test-rmse:4.34418
# [448]	train-rmse:3.68316	test-rmse:4.34415
# [449]	train-rmse:3.68298	test-rmse:4.34417
# [450]	train-rmse:3.68225	test-rmse:4.34399
# [451]	train-rmse:3.68163	test-rmse:4.34393
# [452]	train-rmse:3.68153	test-rmse:4.34388
# [453]	train-rmse:3.68102	test-rmse:4.3437
# [454]	train-rmse:3.68024	test-rmse:4.34365
# [455]	train-rmse:3.67985	test-rmse:4.34373
# [456]	train-rmse:3.67897	test-rmse:4.34354
# [457]	train-rmse:3.67812	test-rmse:4.34303
# [458]	train-rmse:3.6778	test-rmse:4.3429
# [459]	train-rmse:3.67755	test-rmse:4.3429
# [460]	train-rmse:3.67628	test-rmse:4.34241
# [461]	train-rmse:3.6758	test-rmse:4.3423
# [462]	train-rmse:3.67522	test-rmse:4.3421
# [463]	train-rmse:3.67466	test-rmse:4.34187
# [464]	train-rmse:3.67446	test-rmse:4.34189
# [465]	train-rmse:3.67377	test-rmse:4.34168
# [466]	train-rmse:3.67259	test-rmse:4.34101
# [467]	train-rmse:3.67175	test-rmse:4.34085
# [468]	train-rmse:3.67159	test-rmse:4.34085
# [469]	train-rmse:3.67135	test-rmse:4.34076
# [470]	train-rmse:3.67112	test-rmse:4.3408
# [471]	train-rmse:3.67053	test-rmse:4.34088
# [472]	train-rmse:3.6693	test-rmse:4.34032
# [473]	train-rmse:3.66881	test-rmse:4.34011
# [474]	train-rmse:3.66856	test-rmse:4.34004
# [475]	train-rmse:3.66816	test-rmse:4.33993
# [476]	train-rmse:3.66798	test-rmse:4.33995
# [477]	train-rmse:3.6676	test-rmse:4.33998
# [478]	train-rmse:3.66721	test-rmse:4.33998
# [479]	train-rmse:3.66654	test-rmse:4.33993
# [480]	train-rmse:3.66589	test-rmse:4.33988
# [481]	train-rmse:3.66479	test-rmse:4.33926
# [482]	train-rmse:3.66411	test-rmse:4.33916
# [483]	train-rmse:3.66396	test-rmse:4.33912
# [484]	train-rmse:3.66393	test-rmse:4.33911
# [485]	train-rmse:3.66341	test-rmse:4.33902
# [486]	train-rmse:3.66289	test-rmse:4.33906
# [487]	train-rmse:3.66217	test-rmse:4.33901
# [488]	train-rmse:3.66106	test-rmse:4.33844
# [489]	train-rmse:3.66066	test-rmse:4.33841
# [490]	train-rmse:3.6599	test-rmse:4.33824
# [491]	train-rmse:3.6596	test-rmse:4.33815
# [492]	train-rmse:3.65906	test-rmse:4.33803
# [493]	train-rmse:3.65875	test-rmse:4.33806
# [494]	train-rmse:3.65822	test-rmse:4.33814
# [495]	train-rmse:3.65742	test-rmse:4.33785
# [496]	train-rmse:3.65677	test-rmse:4.33763
# [497]	train-rmse:3.65604	test-rmse:4.33739
# [498]	train-rmse:3.65584	test-rmse:4.33736
# [499]	train-rmse:3.65533	test-rmse:4.33742
# [500]	train-rmse:3.6539	test-rmse:4.33732
# [501]	train-rmse:3.6537	test-rmse:4.33729
# [502]	train-rmse:3.6533	test-rmse:4.33712
# [503]	train-rmse:3.65289	test-rmse:4.33712
# [504]	train-rmse:3.65277	test-rmse:4.33714
# [505]	train-rmse:3.65173	test-rmse:4.33708
# [506]	train-rmse:3.65143	test-rmse:4.33699
# [507]	train-rmse:3.65122	test-rmse:4.33699
# [508]	train-rmse:3.65104	test-rmse:4.33711
# [509]	train-rmse:3.65096	test-rmse:4.33714
# [510]	train-rmse:3.65068	test-rmse:4.33714
# [511]	train-rmse:3.64972	test-rmse:4.33704
# [512]	train-rmse:3.64966	test-rmse:4.33704
# [513]	train-rmse:3.64909	test-rmse:4.33683
# [514]	train-rmse:3.6485	test-rmse:4.33665
# [515]	train-rmse:3.64787	test-rmse:4.33644
# [516]	train-rmse:3.64744	test-rmse:4.33632
# [517]	train-rmse:3.64689	test-rmse:4.33634
# [518]	train-rmse:3.64677	test-rmse:4.33633
# [519]	train-rmse:3.64582	test-rmse:4.33622
# [520]	train-rmse:3.64578	test-rmse:4.33621
# [521]	train-rmse:3.64519	test-rmse:4.33626
# [522]	train-rmse:3.645	test-rmse:4.33616
# [523]	train-rmse:3.64441	test-rmse:4.33613
# [524]	train-rmse:3.64393	test-rmse:4.33608
# [525]	train-rmse:3.64351	test-rmse:4.33611
# [526]	train-rmse:3.64258	test-rmse:4.33581
# [527]	train-rmse:3.64173	test-rmse:4.33582
# [528]	train-rmse:3.64158	test-rmse:4.33571
# [529]	train-rmse:3.64149	test-rmse:4.33567
# [530]	train-rmse:3.64097	test-rmse:4.3356
# [531]	train-rmse:3.64039	test-rmse:4.33533
# [532]	train-rmse:3.63976	test-rmse:4.33499
# [533]	train-rmse:3.6395	test-rmse:4.3349
# [534]	train-rmse:3.63851	test-rmse:4.3348
# [535]	train-rmse:3.638	test-rmse:4.33486
# [536]	train-rmse:3.63747	test-rmse:4.33458
# [537]	train-rmse:3.63717	test-rmse:4.33453
# [538]	train-rmse:3.63633	test-rmse:4.33469
# [539]	train-rmse:3.63598	test-rmse:4.33475
# [540]	train-rmse:3.63555	test-rmse:4.3347
# [541]	train-rmse:3.63506	test-rmse:4.33455
# [542]	train-rmse:3.63494	test-rmse:4.33454
# [543]	train-rmse:3.63415	test-rmse:4.33453
# [544]	train-rmse:3.63329	test-rmse:4.33446
# [545]	train-rmse:3.63278	test-rmse:4.33452
# [546]	train-rmse:3.63228	test-rmse:4.33451
# [547]	train-rmse:3.63217	test-rmse:4.33463
# [548]	train-rmse:3.63181	test-rmse:4.33477
# [549]	train-rmse:3.6313	test-rmse:4.33477
# [550]	train-rmse:3.62993	test-rmse:4.33475
# [551]	train-rmse:3.62975	test-rmse:4.33474
# [552]	train-rmse:3.62967	test-rmse:4.33482
# [553]	train-rmse:3.62878	test-rmse:4.33476
# [554]	train-rmse:3.6287	test-rmse:4.33468
# Stopping. Best iteration:
# [544]	train-rmse:3.63329	test-rmse:4.33446

# %%
test = pd.read_csv("/content/test.csv")
holdout = pd.DataFrame({'key': test['key'], 'fare_amount': prediction})
holdout.to_csv('xgb_4m_utc_with_cleaning.csv', index=False)

# %%
import matplotlib.pyplot as plt
fscores = pd.DataFrame({'X': list(model.get_fscore().keys()), 'Y': list(model.get_fscore().values())})
fscores.sort_values(by='Y').plot.bar(x='X')
